# %%
import spacy
import textacy
import re
import numpy as np
import os.path as osp
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES

file_list_path = '/mnt/Alfheim/Data/AMASS_30_SMPL/file_list.lst'
output_path = '/mnt/Alfheim/Data/AMASS_30_SMPL/amass_verb_list.csv'
nlp = spacy.load('en_core_web_lg')
lemmatizer = Lemmatizer(LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES)

# %%
def extract_pos(filename):
    doc = nlp(filename)
    return [token.pos_ for token in doc]

def extract_lemma(filename):
    doc = nlp(filename)
    return [lemmatizer(token.text, token.pos_)[0] for token in doc]

def remove_one_char_tokens(sentence):
    return ' '.join([token for token in sentence.split() if len(token) > 1])

# %%
file_list
# Out:
# ['ACCAD/Female1General_c3d/A1 - Stand_poses.npz',
#  'ACCAD/Female1General_c3d/A10 - lie to crouch_poses.npz',
#  'ACCAD/Female1General_c3d/A11 - crawl forward_poses.npz',
#  'ACCAD/Female1General_c3d/A12 - crawl backwards_poses.npz',
#  'ACCAD/Female1General_c3d/A14 - stand to skip_poses.npz',
#  'ACCAD/Female1General_c3d/A15 - skip to stand_poses.npz',
#  'ACCAD/Female1General_c3d/A2 - Sway t2_poses.npz',
#  'ACCAD/Female1General_c3d/A2 - Sway_poses.npz',
#  'ACCAD/Female1General_c3d/A3 - Swing t2_poses.npz',
#  'ACCAD/Female1General_c3d/A3 - Swing_poses.npz',
#  'ACCAD/Female1General_c3d/A4 - look_poses.npz',
#  'ACCAD/Female1General_c3d/A5 - pick up box_poses.npz',
#  'ACCAD/Female1General_c3d/A6 - lift box_poses.npz',
#  'ACCAD/Female1General_c3d/A6- lift box t2_poses.npz',
#  'ACCAD/Female1General_c3d/A7 - crouch_poses.npz',
#  'ACCAD/Female1General_c3d/A8 - crouch to lie_poses.npz',
#  'ACCAD/Female1General_c3d/A9 - lie t2_poses.npz',
#  'ACCAD/Female1Gestures_c3d/D1 - Urban 1_poses.npz',
#  'ACCAD/Female1Gestures_c3d/D2 - Wait 1_poses.npz',
#  'ACCAD/Female1Gestures_c3d/D3 - Conversation Gestures_poses.npz',
#  'ACCAD/Female1Gestures_c3d/D5 - Random Stuff 2_poses.npz',
#  'ACCAD/Female1Gestures_c3d/D6- CartWheel_poses.npz',
#  'ACCAD/Female1Gestures_c3d/Female1 Subj Calibration_poses.npz',
#  'ACCAD/Female1Running_c3d/C10 -  run backwards stop run forward_poses.npz',
#  'ACCAD/Female1Running_c3d/C11 -  run turn left (90)_poses.npz',
#  'ACCAD/Female1Running_c3d/C13 -  run turn left (135)_poses.npz',
#  'ACCAD/Female1Running_c3d/C14 -  run turn right  (90)_poses.npz',
#  'ACCAD/Female1Running_c3d/C15 -  run turn right  (45)_poses.npz',
#  'ACCAD/Female1Running_c3d/C16 -  run turn right  (135)_poses.npz',
#  'ACCAD/Female1Running_c3d/C19 -  run to hop to walk_poses.npz',
#  'ACCAD/Female1Running_c3d/C2 - Run to stand_poses.npz',
#  'ACCAD/Female1Running_c3d/C20 -  run to jump to walk_poses.npz',
#  'ACCAD/Female1Running_c3d/C21 -  run to pick up box_poses.npz',
#  'ACCAD/Female1Running_c3d/C21 s2 -  run to pick up box_poses.npz',
#  'ACCAD/Female1Running_c3d/C22 -  run with box_poses.npz',
#  'ACCAD/Female1Running_c3d/C24 -  side step left_poses.npz',
#  'ACCAD/Female1Running_c3d/C25 -  side step right_poses.npz',
#  'ACCAD/Female1Running_c3d/C26 -  run to crouch_poses.npz',
#  'ACCAD/Female1Running_c3d/C27 - crouch to run1_poses.npz',
#  'ACCAD/Female1Running_c3d/C3 - Run_poses.npz',
#  'ACCAD/Female1Running_c3d/C4 - Run to walk1_poses.npz',
#  'ACCAD/Female1Running_c3d/C5 - walk to run_poses.npz',
#  'ACCAD/Female1Running_c3d/C6 - stand to run backwards_poses.npz',
#  'ACCAD/Female1Running_c3d/C7 -  run backwards_poses.npz',
#  'ACCAD/Female1Running_c3d/C8 -  run backwards to stand_poses.npz',
#  'ACCAD/Female1Running_c3d/C9 -  run backwards turn run forward_poses.npz',
#  'ACCAD/Female1Walking_c3d/B20 - walk with box_poses.npz',
#  'ACCAD/Female1Walking_c3d/B1 - stand to walk_poses.npz',
#  'ACCAD/Female1Walking_c3d/B10 - walk turn left (45)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B11 - walk turn left (135)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B12 - walk turn right (90)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B13 - walk turn right (45)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B14 - walk turn right (135)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B15 - walk turn around (same direction)_poses.npz',
#  'ACCAD/Female1Walking_c3d/B16 - walk turn change direction_poses.npz',
#  'ACCAD/Female1Walking_c3d/B17 - walk to hop to walk1_poses.npz',
#  'ACCAD/Female1Walking_c3d/B18 - walk to leap to walk_poses.npz',
#  'ACCAD/Female1Walking_c3d/B19 - walk to pick up box_poses.npz',
#  'ACCAD/Female1Walking_c3d/B2 - walk to stand t2_poses.npz',
#  'ACCAD/Female1Walking_c3d/B2 - walk to stand_poses.npz',
#  'ACCAD/Female1Walking_c3d/B21 - put down box to walk_poses.npz',
#  'ACCAD/Female1Walking_c3d/B21 s2 - put down box to walk_poses.npz',
#  'ACCAD/Female1Walking_c3d/B21 s3 - put down box to walk_poses.npz',
#  'ACCAD/Female1Walking_c3d/B22 - side step left_poses.npz',
#  'ACCAD/Female1Walking_c3d/B23 - side step right_poses.npz',
#  'ACCAD/Female1Walking_c3d/B24 - walk to crouch_poses.npz',
#  'ACCAD/Female1Walking_c3d/B25 - crouch to walk1_poses.npz',
#  'ACCAD/Female1Walking_c3d/B27 -skip to walk1_poses.npz',
#  'ACCAD/Female1Walking_c3d/B3 - walk1_poses.npz',
#  'ACCAD/Female1Walking_c3d/B4 - stand to walk back_poses.npz',
#  'ACCAD/Female1Walking_c3d/B5 - walk backwards_poses.npz',
#  'ACCAD/Female1Walking_c3d/B6 - walk backwards to stand_poses.npz',
#  'ACCAD/Female1Walking_c3d/B7 - walk backwards turn forwards_poses.npz',
#  'ACCAD/Female1Walking_c3d/B9 - walk turn left (90)_poses.npz',
#  'ACCAD/Male1General_c3d/General A1 - Stand_poses.npz',
#  'ACCAD/Male1General_c3d/General A10 -  Lie Down to Crouch_poses.npz',
#  'ACCAD/Male1General_c3d/General A11 -   Military Crawl Forward_poses.npz',
#  'ACCAD/Male1General_c3d/General A12 -   Military Crawl Backwards_poses.npz',
#  'ACCAD/Male1General_c3d/General A2 - Sway t2_poses.npz',
#  'ACCAD/Male1General_c3d/General A2 - Sway t3_poses.npz',
#  'ACCAD/Male1General_c3d/General A2 - Sway_poses.npz',
#  'ACCAD/Male1General_c3d/General A3 - Swing Arms While Stand_poses.npz',
#  'ACCAD/Male1General_c3d/General A4 - Look Around_poses.npz',
#  'ACCAD/Male1General_c3d/General A5 - Pick Up Box_poses.npz',
#  'ACCAD/Male1General_c3d/General A6 - Lift Box_poses.npz',
#  'ACCAD/Male1General_c3d/General A7 - Crouch_poses.npz',
#  'ACCAD/Male1General_c3d/General A8 -  Crourch to Lie (forward)_poses.npz',
#  'ACCAD/Male1General_c3d/General A8 - Crouch to Lie Down_poses.npz',
#  'ACCAD/Male1General_c3d/General A9 -   Lie (forward) t2_poses.npz',
#  'ACCAD/Male1General_c3d/General A9 -   Lie (forward)_poses.npz',
#  'ACCAD/Male1General_c3d/General A9 -  Lie Down_poses.npz',
#  'ACCAD/Male1Running_c3d/Run C24 - quick side step left_poses.npz',
#  'ACCAD/Male1Running_c3d/Run C25 - quick side step right_poses.npz',
#  'ACCAD/Male1Walking_c3d/Male1 Cal_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B10 - Walk turn left 45_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B13 - Walk turn right 45_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B15 - Walk turn around_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B16 - Walk turn change_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B17 - Walk 2 hop 2 walk_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B21 - Put Down Box to walk_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B22 - Side step left_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B23 - Side step right_poses.npz',
#  'ACCAD/Male1Walking_c3d/Walk B4 - Stand to Walk Back_poses.npz',
#  'ACCAD/Male2General_c3d/A1- Stand_poses.npz',
#  'ACCAD/Male2General_c3d/A10- Lie to crouch_poses.npz',
#  'ACCAD/Male2General_c3d/A11- Crawl_poses.npz',
#  'ACCAD/Male2General_c3d/A12- Crawl Backwards_poses.npz',
#  'ACCAD/Male2General_c3d/A2- Sway_poses.npz',
#  'ACCAD/Male2General_c3d/A3- Swing arms_poses.npz',
#  'ACCAD/Male2General_c3d/A4- Look Around_poses.npz',
#  'ACCAD/Male2General_c3d/A5- Pick up box_poses.npz',
#  'ACCAD/Male2General_c3d/A6- Box lift_poses.npz',
#  'ACCAD/Male2General_c3d/A7- Crouch_poses.npz',
#  'ACCAD/Male2General_c3d/A8- Crouch to Lie_poses.npz',
#  'ACCAD/Male2General_c3d/A9- Lie_poses.npz',
#  'ACCAD/Male2General_c3d/male2 Calibration_poses.npz',
#  'ACCAD/Male2MartialArtsExtended_c3d/Extended 1_poses.npz',
#  'ACCAD/Male2MartialArtsExtended_c3d/Extended 2_poses.npz',
#  'ACCAD/Male2MartialArtsExtended_c3d/Extended 3_poses.npz',
#  'ACCAD/Male2MartialArtsExtended_c3d/Form 1_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G10-  roundhouse leading left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G11-  roundhouse leading right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G12-  cresent left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G13-  cresent right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G14-  roundhouse body left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G15-  roundhouse body right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G16-  double kick_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G17-  push kick left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G18-  push kick right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G19-  reverse spin cresent left t2_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G19-  reverse spin cresent left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G2 - Sidekick leading left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G20 -  reverse spin cresent right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G3 - front kick_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G3 - Sidekick leading right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G4 -spinning back kick_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G5 -  back kick_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G6 -  axe kick_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G7 -  capoera_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G8 -  roundhouse left_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G9 -  roundhouse right_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/G9-  roundhouse right t2_poses.npz',
#  'ACCAD/Male2MartialArtsKicks_c3d/male2 Subject Cal 2_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E1 -  Jab left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E10 - body hook right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E11 - backfist left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E11 - body hook right t2_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E12 - backfist right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E13 - body cross left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E14 - body cross left t2_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E14 - body cross right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E15 - body jab right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E16 - body jab left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E2 -  Jab right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E3 -  cross left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E4 -  cross right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E5 -  hook left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E6 -  hook right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E7 - uppercut left_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E8 - uppercut right_poses.npz',
#  'ACCAD/Male2MartialArtsPunches_c3d/E9 - body hook left_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D1 - stand to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D10 - victory 2_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D11 - ready to taunt one to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D12 - ready to taunt two to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D13 -crouch to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D14 -ready to crouch_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D15 - switch stance_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D16 - switch stance and bounce_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D2 - walk to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D3 - run to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D4 - ready to relax_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D5 - ready to walk away_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D7 - walk to bow_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D8 - bow to ready_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D9 - t2 - male2 blanks_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D9 - victory 1_poses.npz',
#  'ACCAD/Male2MartialArtsStances_c3d/D9 - warm up to ready to warm up_poses.npz',
#  'ACCAD/Male2Running_c3d/C1 - stand to run_poses.npz',
#  'ACCAD/Male2Running_c3d/C11 - run turn left 90_poses.npz',
#  'ACCAD/Male2Running_c3d/C12 - run turn left 45_poses.npz',
#  'ACCAD/Male2Running_c3d/C13 - run turn left 135_poses.npz',
#  'ACCAD/Male2Running_c3d/C14 - run turn right 90_poses.npz',
#  'ACCAD/Male2Running_c3d/C15 - run turn right 45_poses.npz',
#  'ACCAD/Male2Running_c3d/C16 - run turn right 135_poses.npz',
#  'ACCAD/Male2Running_c3d/C17 - run change direction_poses.npz',
#  'ACCAD/Male2Running_c3d/C18 - run to hop to walk_poses.npz',
#  'ACCAD/Male2Running_c3d/C19 - run to jump to walk_poses.npz',
#  'ACCAD/Male2Running_c3d/C20 - run to pickup box_poses.npz',
#  'ACCAD/Male2Running_c3d/C23 - put down box to run_poses.npz',
#  'ACCAD/Male2Running_c3d/C24 - quick sidestep left_poses.npz',
#  'ACCAD/Male2Running_c3d/C25 - quick sidestep right_poses.npz',
#  'ACCAD/Male2Running_c3d/C26 - run to crouch_poses.npz',
#  'ACCAD/Male2Running_c3d/C3 - run_poses.npz',
#  'ACCAD/Male2Running_c3d/C4 - run to walk a_poses.npz',
#  'ACCAD/Male2Running_c3d/C4 - run to walk_poses.npz',
#  'ACCAD/Male2Running_c3d/C5 - walk to run_poses.npz',
#  'ACCAD/Male2Running_c3d/C6 - stand to run backwards_poses.npz',
#  'ACCAD/Male2Running_c3d/C7 - run backwards t2_poses.npz',
#  'ACCAD/Male2Running_c3d/C8 - run backwards to stand_poses.npz',
#  'ACCAD/Male2Running_c3d/C9 - run backwards turn run forward_poses.npz',
#  'ACCAD/Male2Walking_c3d/B10 -  Walk turn left 45_poses.npz',
#  'ACCAD/Male2Walking_c3d/B11 -  Walk turn left 135_poses.npz',
#  'ACCAD/Male2Walking_c3d/B13 -  Walk turn right 90_poses.npz',
#  'ACCAD/Male2Walking_c3d/B14 -  Walk turn right 45 t2_poses.npz',
#  'ACCAD/Male2Walking_c3d/B14 -  Walk turn right 45_poses.npz',
#  'ACCAD/Male2Walking_c3d/B15 -  Walk turn around_poses.npz',
#  'ACCAD/Male2Walking_c3d/B17 -  Walk to hop to walk a_poses.npz',
#  'ACCAD/Male2Walking_c3d/B17 -  Walk to hop to walk_poses.npz',
#  'ACCAD/Male2Walking_c3d/B18 -  Walk to leap to walk t2_poses.npz',
#  'ACCAD/Male2Walking_c3d/B18 -  Walk to leap to walk t3_poses.npz',
#  'ACCAD/Male2Walking_c3d/B18 -  Walk to leap to walk_poses.npz',
#  'ACCAD/Male2Walking_c3d/B19 -  Walk to pickup box_poses.npz',
#  'ACCAD/Male2Walking_c3d/B20 -  Walk with box_poses.npz',
#  'ACCAD/Male2Walking_c3d/B21 -  put down box to walk a_poses.npz',
#  'ACCAD/Male2Walking_c3d/B21 -  put down box to walk_poses.npz',
#  'ACCAD/Male2Walking_c3d/B22 -  side step left_poses.npz',
#  'ACCAD/Male2Walking_c3d/B23 -  side step right_poses.npz',
#  'ACCAD/Male2Walking_c3d/B24 -  walk to crouch_poses.npz',
#  'ACCAD/Male2Walking_c3d/B26 -  walk to skip_poses.npz',
#  'ACCAD/Male2Walking_c3d/B27 -  skip to walk a_poses.npz',
#  'ACCAD/Male2Walking_c3d/B4 - Stand to Walk backwards_poses.npz',
#  'ACCAD/Male2Walking_c3d/B5 -  Walk backwards_poses.npz',
#  'ACCAD/Male2Walking_c3d/B9 -  Walk turn left 90_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E1 - Turn around right_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E10 - side step right_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E11 - block left high_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E12 - block left low_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E13 - block right high_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E14 - block right low_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E15 - block left middle_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E16 - block right middle_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E17 - block middle high_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E18 - block middle low_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E19 - dodge left t2_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E19 - dodge left_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E2 - Turn around left_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E20 - dodge right_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E21 - duck left_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E22 - duck right_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E3 - advance_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E4 - quick advance_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E5 - retreat_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E6 - quick retreat_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E7 - super fast advance_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E8 - bounce_poses.npz',
#  'ACCAD/MartialArtsWalksTurns_c3d/E9 - side step left_poses.npz',
#  'ACCAD/s001/EricCamper04_poses.npz',
#  'ACCAD/s007/QkWalk1_poses.npz',
#  'ACCAD/s008/Run1_poses.npz',
#  'ACCAD/s009/Sprint1_poses.npz',
#  'ACCAD/s011/walkdog_poses.npz',
#  'BioMotionLab_NTroje/rub001/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub001/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub001/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub001/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub001/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub001/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0007_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0008_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0009_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0010_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0011_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0012_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0013_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0014_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub001/0015_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0016_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0017_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub001/0018_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0019_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub001/0020_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub001/0021_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub002/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub002/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub002/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub002/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub002/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0007_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0008_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0009_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0010_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0011_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0012_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0013_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0014_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0015_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0016_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0017_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub002/0018_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0019_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0020_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0021_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub002/0022_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub002/0023_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub002/0024_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub003/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub003/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub003/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub003/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub003/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub003/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0007_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0008_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0009_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0010_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0011_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0012_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0014_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0015_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0016_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0017_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub003/0018_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0019_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0020_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0021_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub003/0023_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub003/0024_scamper1_poses.npz',
#  'BioMotionLab_NTroje/rub003/0025_scamper2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub004/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub004/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub004/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub004/0004_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0005_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0006_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0007_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0008_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0009_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0010_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0011_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0012_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0013_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0014_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0015_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub004/0016_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0017_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0018_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub004/0019_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub004/0020_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub004/0021_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub005/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub005/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub005/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub005/0004_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0005_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0006_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0007_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0008_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0009_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0010_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0011_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0012_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0014_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0015_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0016_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub005/0017_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0018_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0019_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0021_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub005/0022_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub005/0023_scamper1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub006/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub006/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub006/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub006/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub006/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0007_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0008_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0009_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0010_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0011_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0012_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0013_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0014_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0015_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0016_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0017_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub006/0018_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0019_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0020_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0021_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub006/0022_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub006/0023_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub006/0024_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub007/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub007/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub007/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub007/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub007/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub007/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0007_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0008_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0009_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0010_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0011_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0012_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0013_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0014_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0015_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0016_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub007/0017_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0018_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub007/0019_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub007/0021_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub008/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub008/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub008/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub008/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub008/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub008/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub008/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub008/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub008/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub008/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub008/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub008/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub008/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub008/0030_scamper1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub009/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub009/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub009/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub009/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub009/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub009/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub009/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub009/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub009/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub009/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub009/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub009/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub009/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub009/0030_scamper1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0014_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub010/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub010/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub010/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub010/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub010/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub010/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub010/0009_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0010_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub010/0011_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub010/0012_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0013_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0015_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0016_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0017_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0018_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0019_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0020_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub010/0021_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0022_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0023_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub010/0024_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0025_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub010/0026_kicking3_poses.npz',
#  'BioMotionLab_NTroje/rub010/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub010/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub010/0029_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub011/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub011/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub011/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub011/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub011/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub011/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub011/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub011/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub011/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub011/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub011/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub011/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub011/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub011/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub011/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub012/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub012/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub012/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub012/0004_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0005_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0006_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub012/0007_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub012/0008_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub012/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub012/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub012/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub012/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub012/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0027_kicking3_poses.npz',
#  'BioMotionLab_NTroje/rub012/0028_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub012/0029_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub012/0030_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub012/0031_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub014/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0000_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub014/0001_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub014/0002_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub014/0003_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub014/0004_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub014/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub014/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub014/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub014/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub014/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub014/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub014/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub014/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub014/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub014/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub015/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub015/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub015/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub015/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub015/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub015/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub015/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub015/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub015/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0019_lifting_light3_poses.npz',
#  'BioMotionLab_NTroje/rub015/0020_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0021_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0022_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub015/0023_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0025_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub015/0026_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0027_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0028_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub015/0029_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub015/0030_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub015/0031_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub016/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub016/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub016/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub016/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub016/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub016/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub016/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub016/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub016/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub016/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub016/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub016/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub016/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub017/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub017/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub017/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub017/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub017/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub017/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub017/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub017/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub017/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub017/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub017/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub017/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub017/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub017/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub018/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub018/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub018/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub018/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub018/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub018/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub018/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub018/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub018/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub018/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub018/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub018/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub018/0030_jumping3_poses.npz',
#  'BioMotionLab_NTroje/rub018/0031_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub020/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub020/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub020/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub020/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub020/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub020/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub020/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub020/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub020/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub020/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub020/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub020/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub020/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub021/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub021/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub021/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub021/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub021/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub021/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub021/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub021/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub021/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub021/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub021/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub021/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub021/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub022/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub022/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub022/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub022/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub022/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub022/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub022/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub022/0009_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0011_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub022/0012_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0013_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0014_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0015_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0016_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0017_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0018_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0019_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0020_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub022/0022_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0025_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0026_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub022/0027_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub022/0028_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub022/0029_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub023/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub023/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub023/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub023/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub023/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub023/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub023/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub023/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub023/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub023/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub023/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub023/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub023/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub023/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub025/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub025/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub025/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub025/0004_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0005_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0006_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub025/0007_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub025/0008_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0009_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0010_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub025/0011_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub025/0012_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0013_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0014_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0015_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0016_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0017_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0018_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0019_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0020_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub025/0021_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0022_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0023_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub025/0024_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0025_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0026_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub025/0027_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub025/0028_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub025/0029_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub026/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub026/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub026/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub026/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub026/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub026/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub026/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub026/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub026/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub026/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub026/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub026/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub026/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub026/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub027/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub027/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub027/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub027/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub027/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub027/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub027/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub027/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub027/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub027/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub027/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub027/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub027/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub027/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub027/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub028/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub028/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub028/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub028/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub028/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub028/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub028/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub028/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub028/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub028/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub028/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub028/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub029/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub029/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub029/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub029/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub029/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub029/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub029/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub029/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub029/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0021_catching_and_throwing_poses.npz',
#  'BioMotionLab_NTroje/rub029/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0023_throwing_hard2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0024_throwing_hard3_poses.npz',
#  'BioMotionLab_NTroje/rub029/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub029/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub029/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub029/0031_rom_poses.npz',
#  'BioMotionLab_NTroje/rub030/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub030/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub030/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub030/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub030/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub030/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub030/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0016_sitting2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0017_lifting_light1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0018_lifting_light2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0019_lifting_heavy1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0020_lifting_heavy2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0022_throwing_hard1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0025_kicking1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0026_kicking2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0027_circle_walk_poses.npz',
#  'BioMotionLab_NTroje/rub030/0028_jumping1_poses.npz',
#  'BioMotionLab_NTroje/rub030/0029_jumping2_poses.npz',
#  'BioMotionLab_NTroje/rub030/0030_scamper_poses.npz',
#  'BioMotionLab_NTroje/rub031/0000_treadmill_norm_poses.npz',
#  'BioMotionLab_NTroje/rub031/0001_treadmill_fast_poses.npz',
#  'BioMotionLab_NTroje/rub031/0002_treadmill_slow_poses.npz',
#  'BioMotionLab_NTroje/rub031/0003_treadmill_jog_poses.npz',
#  'BioMotionLab_NTroje/rub031/0004_motorcycle_poses.npz',
#  'BioMotionLab_NTroje/rub031/0005_normal_walk1_poses.npz',
#  'BioMotionLab_NTroje/rub031/0006_normal_walk2_poses.npz',
#  'BioMotionLab_NTroje/rub031/0007_normal_walk3_poses.npz',
#  'BioMotionLab_NTroje/rub031/0008_normal_walk4_poses.npz',
#  'BioMotionLab_NTroje/rub031/0009_normal_jog1_poses.npz',
#  'BioMotionLab_NTroje/rub031/0010_normal_jog2_poses.npz',
#  'BioMotionLab_NTroje/rub031/0011_normal_jog3_poses.npz',
#  'BioMotionLab_NTroje/rub031/0012_normal_jog4_poses.npz',
#  'BioMotionLab_NTroje/rub031/0013_knocking1_poses.npz',
#  'BioMotionLab_NTroje/rub031/0014_knocking2_poses.npz',
#  'BioMotionLab_NTroje/rub031/0015_sitting1_poses.npz',
#  'BioMotionLab_NTroje/rub031/0016_sitting2_poses.npz',
#  ...]

# %%
file_list = [l.replace('/mnt/Alfheim/Data/AMASS_30_SMPL/', '').strip() for l in open(file_list_path).readlines()]
filename_list = [osp.splitext(osp.basename(l.strip()))[0] for l in open(file_list_path).readlines()]
filename_list = [fn.lower() for fn in filename_list]
filename_list = [fn.replace('_', ' ') for fn in filename_list]
filename_list = [fn.replace('poses', '') for fn in filename_list]
filename_list = [re.sub(r'[^a-zA-Z ]', '', fn) for fn in filename_list]
filename_list = [re.sub(' +', ' ', fn) for fn in filename_list]
filename_list = [remove_one_char_tokens(fn) for fn in filename_list]
filename_list
# Out:
# ['stand',
#  'lie to crouch',
#  'crawl forward',
#  'crawl backwards',
#  'stand to skip',
#  'skip to stand',
#  'sway',
#  'sway',
#  'swing',
#  'swing',
#  'look',
#  'pick up box',
#  'lift box',
#  'lift box',
#  'crouch',
#  'crouch to lie',
#  'lie',
#  'urban',
#  'wait',
#  'conversation gestures',
#  'random stuff',
#  'cartwheel',
#  'female subj calibration',
#  'run backwards stop run forward',
#  'run turn left',
#  'run turn left',
#  'run turn right',
#  'run turn right',
#  'run turn right',
#  'run to hop to walk',
#  'run to stand',
#  'run to jump to walk',
#  'run to pick up box',
#  'run to pick up box',
#  'run with box',
#  'side step left',
#  'side step right',
#  'run to crouch',
#  'crouch to run',
#  'run',
#  'run to walk',
#  'walk to run',
#  'stand to run backwards',
#  'run backwards',
#  'run backwards to stand',
#  'run backwards turn run forward',
#  'walk with box',
#  'stand to walk',
#  'walk turn left',
#  'walk turn left',
#  'walk turn right',
#  'walk turn right',
#  'walk turn right',
#  'walk turn around same direction',
#  'walk turn change direction',
#  'walk to hop to walk',
#  'walk to leap to walk',
#  'walk to pick up box',
#  'walk to stand',
#  'walk to stand',
#  'put down box to walk',
#  'put down box to walk',
#  'put down box to walk',
#  'side step left',
#  'side step right',
#  'walk to crouch',
#  'crouch to walk',
#  'skip to walk',
#  'walk',
#  'stand to walk back',
#  'walk backwards',
#  'walk backwards to stand',
#  'walk backwards turn forwards',
#  'walk turn left',
#  'general stand',
#  'general lie down to crouch',
#  'general military crawl forward',
#  'general military crawl backwards',
#  'general sway',
#  'general sway',
#  'general sway',
#  'general swing arms while stand',
#  'general look around',
#  'general pick up box',
#  'general lift box',
#  'general crouch',
#  'general crourch to lie forward',
#  'general crouch to lie down',
#  'general lie forward',
#  'general lie forward',
#  'general lie down',
#  'run quick side step left',
#  'run quick side step right',
#  'male cal',
#  'walk walk turn left',
#  'walk walk turn right',
#  'walk walk turn around',
#  'walk walk turn change',
#  'walk walk hop walk',
#  'walk put down box to walk',
#  'walk side step left',
#  'walk side step right',
#  'walk stand to walk back',
#  'stand',
#  'lie to crouch',
#  'crawl',
#  'crawl backwards',
#  'sway',
#  'swing arms',
#  'look around',
#  'pick up box',
#  'box lift',
#  'crouch',
#  'crouch to lie',
#  'lie',
#  'male calibration',
#  'extended',
#  'extended',
#  'extended',
#  'form',
#  'roundhouse leading left',
#  'roundhouse leading right',
#  'cresent left',
#  'cresent right',
#  'roundhouse body left',
#  'roundhouse body right',
#  'double kick',
#  'push kick left',
#  'push kick right',
#  'reverse spin cresent left',
#  'reverse spin cresent left',
#  'sidekick leading left',
#  'reverse spin cresent right',
#  'front kick',
#  'sidekick leading right',
#  'spinning back kick',
#  'back kick',
#  'axe kick',
#  'capoera',
#  'roundhouse left',
#  'roundhouse right',
#  'roundhouse right',
#  'male subject cal',
#  'jab left',
#  'body hook right',
#  'backfist left',
#  'body hook right',
#  'backfist right',
#  'body cross left',
#  'body cross left',
#  'body cross right',
#  'body jab right',
#  'body jab left',
#  'jab right',
#  'cross left',
#  'cross right',
#  'hook left',
#  'hook right',
#  'uppercut left',
#  'uppercut right',
#  'body hook left',
#  'stand to ready',
#  'victory',
#  'ready to taunt one to ready',
#  'ready to taunt two to ready',
#  'crouch to ready',
#  'ready to crouch',
#  'switch stance',
#  'switch stance and bounce',
#  'walk to ready',
#  'run to ready',
#  'ready to relax',
#  'ready to walk away',
#  'walk to bow',
#  'bow to ready',
#  'male blanks',
#  'victory',
#  'warm up to ready to warm up',
#  'stand to run',
#  'run turn left',
#  'run turn left',
#  'run turn left',
#  'run turn right',
#  'run turn right',
#  'run turn right',
#  'run change direction',
#  'run to hop to walk',
#  'run to jump to walk',
#  'run to pickup box',
#  'put down box to run',
#  'quick sidestep left',
#  'quick sidestep right',
#  'run to crouch',
#  'run',
#  'run to walk',
#  'run to walk',
#  'walk to run',
#  'stand to run backwards',
#  'run backwards',
#  'run backwards to stand',
#  'run backwards turn run forward',
#  'walk turn left',
#  'walk turn left',
#  'walk turn right',
#  'walk turn right',
#  'walk turn right',
#  'walk turn around',
#  'walk to hop to walk',
#  'walk to hop to walk',
#  'walk to leap to walk',
#  'walk to leap to walk',
#  'walk to leap to walk',
#  'walk to pickup box',
#  'walk with box',
#  'put down box to walk',
#  'put down box to walk',
#  'side step left',
#  'side step right',
#  'walk to crouch',
#  'walk to skip',
#  'skip to walk',
#  'stand to walk backwards',
#  'walk backwards',
#  'walk turn left',
#  'turn around right',
#  'side step right',
#  'block left high',
#  'block left low',
#  'block right high',
#  'block right low',
#  'block left middle',
#  'block right middle',
#  'block middle high',
#  'block middle low',
#  'dodge left',
#  'dodge left',
#  'turn around left',
#  'dodge right',
#  'duck left',
#  'duck right',
#  'advance',
#  'quick advance',
#  'retreat',
#  'quick retreat',
#  'super fast advance',
#  'bounce',
#  'side step left',
#  'ericcamper',
#  'qkwalk',
#  'run',
#  'sprint',
#  'walkdog',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'knocking',
#  'knocking',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'scamper',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'jumping',
#  'sitting',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'knocking',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'sitting',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'scamper',
#  'sitting',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'motorcycle',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'sitting',
#  'motorcycle',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill slow',
#  'treadmill jog',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'knocking',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'knocking',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'catching and throwing',
#  'throwing hard',
#  'throwing hard',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'rom',
#  'treadmill norm',
#  'treadmill fast',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  'lifting light',
#  'lifting light',
#  'lifting heavy',
#  'lifting heavy',
#  'throwing hard',
#  'kicking',
#  'kicking',
#  'circle walk',
#  'jumping',
#  'jumping',
#  'scamper',
#  'treadmill norm',
#  'treadmill fast',
#  'treadmill slow',
#  'treadmill jog',
#  'motorcycle',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal walk',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'normal jog',
#  'knocking',
#  'knocking',
#  'sitting',
#  'sitting',
#  ...]

# %%
to_count = 0
for fn in filename_list:
    tokens = fn.split()
    if 'to' in tokens:
        to_count += 1
        continue
print(f'TO found: {to_count}/{len(filename_list)}')
# Out:
# TO found: 216/13232

# %%
print('Extracting POS')
filename_pos = [extract_pos(fn) for fn in filename_list]
# Out:
# Extracting POS

# %%
print('Extracting lemmas')
filename_lemma = [extract_lemma(fn) for fn in filename_list]
# Out:
# Extracting lemmas

# %%
verb_list = list()
fragmented_verbs = ['walk', 'run', 'jump', 'turn', 'greet', 'fight', 'sit', 
                    'stand', 'pose', 'gesture', 'push', 'pull', 'kick', 
                    'jog', 'dance', 'stretch']

for fn, pos_list, lemma_list in zip(filename_list, filename_pos, filename_lemma):
    print(lemma_list, pos_list)
    fn_verbs = list()
    if pos_list.count('VERB') > 0:
        verb_idx = [i for i, pos in enumerate(pos_list) if pos == 'VERB']
        fn_verbs += [lemma_list[vi] for vi in verb_idx]
        
    if pos_list.count('NOUN') > 0:
        noun_idx = [i for i, pos in enumerate(pos_list) if pos == 'NOUN']
        for v in fragmented_verbs:
            for noun in [fn.split()[i] for i in noun_idx]:
                if v in noun:
                    fn_verbs.append(v)

    verb_list.append(list(set(fn_verbs)))
# Out:
# ['stand'] ['VERB']
# ['lie', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['crawl', 'forward'] ['VERB', 'ADV']
# ['crawl', 'backwards'] ['VERB', 'ADV']
# ['stand', 'to', 'skip'] ['VERB', 'PART', 'VERB']
# ['skip', 'to', 'stand'] ['VERB', 'PART', 'VERB']
# ['sway'] ['VERB']
# ['sway'] ['VERB']
# ['swing'] ['NOUN']
# ['swing'] ['NOUN']
# ['look'] ['VERB']
# ['pick', 'up', 'box'] ['VERB', 'PART', 'NOUN']
# ['lift', 'box'] ['NOUN', 'NOUN']
# ['lift', 'box'] ['NOUN', 'NOUN']
# ['crouch'] ['VERB']
# ['crouch', 'to', 'lie'] ['VERB', 'PART', 'VERB']
# ['lie'] ['VERB']
# ['urban'] ['ADJ']
# ['wait'] ['VERB']
# ['conversation', 'gesture'] ['NOUN', 'NOUN']
# ['random', 'stuff'] ['ADJ', 'NOUN']
# ['cartwheel'] ['NOUN']
# ['female', 'subj', 'calibration'] ['ADJ', 'NOUN', 'NOUN']
# ['run', 'backwards', 'stop', 'run', 'forward'] ['VERB', 'ADV', 'VERB', 'VERB', 'ADV']
# ['run', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['run', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'to', 'hop', 'to', 'walk'] ['VERB', 'ADP', 'NOUN', 'PART', 'VERB']
# ['run', 'to', 'stand'] ['VERB', 'PART', 'VERB']
# ['run', 'to', 'jump', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['run', 'to', 'pick', 'up', 'box'] ['VERB', 'PART', 'VERB', 'PART', 'NOUN']
# ['run', 'to', 'pick', 'up', 'box'] ['VERB', 'PART', 'VERB', 'PART', 'NOUN']
# ['run', 'with', 'box'] ['VERB', 'ADP', 'NOUN']
# ['side', 'step', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['side', 'step', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['run', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['crouch', 'to', 'run'] ['VERB', 'PART', 'VERB']
# ['run'] ['VERB']
# ['run', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['walk', 'to', 'run'] ['VERB', 'PART', 'VERB']
# ['stand', 'to', 'run', 'backwards'] ['VERB', 'PART', 'VERB', 'ADV']
# ['run', 'backwards'] ['VERB', 'ADV']
# ['run', 'backwards', 'to', 'stand'] ['VERB', 'ADV', 'PART', 'VERB']
# ['run', 'backwards', 'turn', 'run', 'forward'] ['VERB', 'ADV', 'NOUN', 'VERB', 'ADV']
# ['walk', 'with', 'box'] ['VERB', 'ADP', 'NOUN']
# ['stand', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'around', 'same', 'direction'] ['VERB', 'VERB', 'PART', 'ADJ', 'NOUN']
# ['walk', 'turn', 'change', 'direction'] ['VERB', 'NOUN', 'NOUN', 'NOUN']
# ['walk', 'to', 'hop', 'to', 'walk'] ['VERB', 'ADP', 'NOUN', 'PART', 'VERB']
# ['walk', 'to', 'leap', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['walk', 'to', 'pick', 'up', 'box'] ['VERB', 'PART', 'VERB', 'PART', 'NOUN']
# ['walk', 'to', 'stand'] ['VERB', 'PART', 'VERB']
# ['walk', 'to', 'stand'] ['VERB', 'PART', 'VERB']
# ['put', 'down', 'box', 'to', 'walk'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['put', 'down', 'box', 'to', 'walk'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['put', 'down', 'box', 'to', 'walk'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['side', 'step', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['side', 'step', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['walk', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['crouch', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['skip', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['walk'] ['VERB']
# ['stand', 'to', 'walk', 'back'] ['VERB', 'PART', 'VERB', 'ADV']
# ['walk', 'backwards'] ['VERB', 'ADV']
# ['walk', 'backwards', 'to', 'stand'] ['VERB', 'ADV', 'PART', 'VERB']
# ['walk', 'backwards', 'turn', 'forwards'] ['VERB', 'ADV', 'VERB', 'ADV']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['general', 'stand'] ['ADJ', 'NOUN']
# ['general', 'lie', 'down', 'to', 'crouch'] ['ADJ', 'VERB', 'ADV', 'PART', 'VERB']
# ['general', 'military', 'crawl', 'forward'] ['ADJ', 'NOUN', 'VERB', 'ADV']
# ['general', 'military', 'crawl', 'backwards'] ['ADJ', 'ADJ', 'NOUN', 'ADV']
# ['general', 'sway'] ['ADJ', 'NOUN']
# ['general', 'sway'] ['ADJ', 'NOUN']
# ['general', 'sway'] ['ADJ', 'NOUN']
# ['general', 'swing', 'arm', 'while', 'stand'] ['ADJ', 'NOUN', 'NOUN', 'ADP', 'VERB']
# ['general', 'look', 'around'] ['ADJ', 'VERB', 'ADV']
# ['general', 'pick', 'up', 'box'] ['ADJ', 'VERB', 'PART', 'NOUN']
# ['general', 'lift', 'box'] ['ADJ', 'NOUN', 'NOUN']
# ['general', 'crouch'] ['ADJ', 'NOUN']
# ['general', 'crourch', 'to', 'lie', 'forward'] ['ADJ', 'NOUN', 'PART', 'VERB', 'ADV']
# ['general', 'crouch', 'to', 'lie', 'down'] ['ADJ', 'VERB', 'PART', 'VERB', 'PART']
# ['general', 'lie', 'forward'] ['ADJ', 'VERB', 'ADV']
# ['general', 'lie', 'forward'] ['ADJ', 'VERB', 'ADV']
# ['general', 'lie', 'down'] ['ADJ', 'VERB', 'PART']
# ['run', 'quick', 'side', 'step', 'leave'] ['VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB']
# ['run', 'quick', 'side', 'step', 'right'] ['VERB', 'ADJ', 'NOUN', 'NOUN', 'ADV']
# ['male', 'cal'] ['ADJ', 'X']
# ['walk', 'walk', 'turn', 'leave'] ['VERB', 'NOUN', 'NOUN', 'VERB']
# ['walk', 'walk', 'turn', 'right'] ['VERB', 'NOUN', 'VERB', 'ADV']
# ['walk', 'walk', 'turn', 'around'] ['VERB', 'NOUN', 'VERB', 'PART']
# ['walk', 'walk', 'turn', 'change'] ['VERB', 'NOUN', 'NOUN', 'NOUN']
# ['walk', 'walk', 'hop', 'walk'] ['VERB', 'NOUN', 'NOUN', 'NOUN']
# ['walk', 'put', 'down', 'box', 'to', 'walk'] ['VERB', 'VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['walk', 'side', 'step', 'leave'] ['VERB', 'NOUN', 'NOUN', 'VERB']
# ['walk', 'side', 'step', 'right'] ['VERB', 'NOUN', 'NOUN', 'ADV']
# ['walk', 'stand', 'to', 'walk', 'back'] ['VERB', 'NOUN', 'PART', 'VERB', 'ADV']
# ['stand'] ['VERB']
# ['lie', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['crawl'] ['NOUN']
# ['crawl', 'backwards'] ['VERB', 'ADV']
# ['sway'] ['VERB']
# ['swing', 'arm'] ['NOUN', 'NOUN']
# ['look', 'around'] ['VERB', 'ADV']
# ['pick', 'up', 'box'] ['VERB', 'PART', 'NOUN']
# ['box', 'lift'] ['NOUN', 'NOUN']
# ['crouch'] ['VERB']
# ['crouch', 'to', 'lie'] ['VERB', 'PART', 'VERB']
# ['lie'] ['VERB']
# ['male', 'calibration'] ['ADJ', 'NOUN']
# ['extend'] ['VERB']
# ['extend'] ['VERB']
# ['extend'] ['VERB']
# ['form'] ['NOUN']
# ['roundhouse', 'lead', 'leave'] ['ADJ', 'VERB', 'VERB']
# ['roundhouse', 'lead', 'right'] ['VERB', 'VERB', 'ADV']
# ['cresent', 'leave'] ['NOUN', 'VERB']
# ['cresent', 'right'] ['NOUN', 'ADV']
# ['roundhouse', 'body', 'leave'] ['ADJ', 'NOUN', 'VERB']
# ['roundhouse', 'body', 'right'] ['ADJ', 'NOUN', 'ADV']
# ['double', 'kick'] ['ADJ', 'NOUN']
# ['push', 'kick', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['push', 'kick', 'right'] ['VERB', 'NOUN', 'ADJ']
# ['reverse', 'spin', 'cresent', 'leave'] ['ADV', 'NOUN', 'NOUN', 'VERB']
# ['reverse', 'spin', 'cresent', 'leave'] ['ADV', 'NOUN', 'NOUN', 'VERB']
# ['sidekick', 'lead', 'leave'] ['NOUN', 'VERB', 'VERB']
# ['reverse', 'spin', 'cresent', 'right'] ['ADV', 'NOUN', 'NOUN', 'NOUN']
# ['front', 'kick'] ['ADJ', 'NOUN']
# ['sidekick', 'lead', 'right'] ['NOUN', 'VERB', 'ADV']
# ['spin', 'back', 'kick'] ['VERB', 'ADV', 'NOUN']
# ['back', 'kick'] ['ADV', 'NOUN']
# ['axe', 'kick'] ['NOUN', 'NOUN']
# ['capoera'] ['NOUN']
# ['roundhouse', 'leave'] ['VERB', 'VERB']
# ['roundhouse', 'right'] ['VERB', 'ADV']
# ['roundhouse', 'right'] ['VERB', 'ADV']
# ['male', 'subject', 'cal'] ['ADJ', 'NOUN', 'X']
# ['jab', 'leave'] ['VERB', 'VERB']
# ['body', 'hook', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['backfist', 'leave'] ['NOUN', 'VERB']
# ['body', 'hook', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['backfist', 'right'] ['VERB', 'ADV']
# ['body', 'cros', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['body', 'cros', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['body', 'cros', 'right'] ['NOUN', 'VERB', 'ADV']
# ['body', 'jab', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['body', 'jab', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['jab', 'right'] ['VERB', 'ADV']
# ['cros', 'leave'] ['NOUN', 'VERB']
# ['cros', 'right'] ['VERB', 'ADV']
# ['hook', 'leave'] ['VERB', 'VERB']
# ['hook', 'right'] ['VERB', 'ADV']
# ['uppercut', 'leave'] ['NOUN', 'VERB']
# ['uppercut', 'right'] ['VERB', 'ADV']
# ['body', 'hook', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['stand', 'to', 'ready'] ['VERB', 'ADP', 'ADJ']
# ['victory'] ['NOUN']
# ['ready', 'to', 'taunt', 'one', 'to', 'ready'] ['ADJ', 'PART', 'VERB', 'PRON', 'PART', 'ADJ']
# ['ready', 'to', 'taunt', 'two', 'to', 'ready'] ['ADJ', 'PART', 'VERB', 'NUM', 'PART', 'ADJ']
# ['crouch', 'to', 'ready'] ['VERB', 'PART', 'ADJ']
# ['ready', 'to', 'crouch'] ['ADJ', 'PART', 'VERB']
# ['switch', 'stance'] ['VERB', 'NOUN']
# ['switch', 'stance', 'and', 'bounce'] ['VERB', 'NOUN', 'CCONJ', 'NOUN']
# ['walk', 'to', 'ready'] ['VERB', 'ADP', 'ADJ']
# ['run', 'to', 'ready'] ['VERB', 'ADP', 'ADJ']
# ['ready', 'to', 'relax'] ['ADJ', 'PART', 'VERB']
# ['ready', 'to', 'walk', 'away'] ['ADJ', 'PART', 'VERB', 'ADV']
# ['walk', 'to', 'bow'] ['VERB', 'PART', 'VERB']
# ['bow', 'to', 'ready'] ['VERB', 'ADP', 'ADJ']
# ['male', 'blank'] ['NOUN', 'NOUN']
# ['victory'] ['NOUN']
# ['warm', 'up', 'to', 'ready', 'to', 'warm', 'up'] ['ADJ', 'PART', 'PART', 'ADJ', 'PART', 'VERB', 'PART']
# ['stand', 'to', 'run'] ['VERB', 'PART', 'VERB']
# ['run', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['run', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['run', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'turn', 'right'] ['VERB', 'NOUN', 'ADV']
# ['run', 'change', 'direction'] ['VERB', 'NOUN', 'NOUN']
# ['run', 'to', 'hop', 'to', 'walk'] ['VERB', 'ADP', 'NOUN', 'PART', 'VERB']
# ['run', 'to', 'jump', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['run', 'to', 'pickup', 'box'] ['VERB', 'ADP', 'NOUN', 'NOUN']
# ['put', 'down', 'box', 'to', 'run'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['quick', 'sidestep', 'leave'] ['ADJ', 'NOUN', 'VERB']
# ['quick', 'sidestep', 'right'] ['ADJ', 'VERB', 'NOUN']
# ['run', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['run'] ['VERB']
# ['run', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['run', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['walk', 'to', 'run'] ['VERB', 'PART', 'VERB']
# ['stand', 'to', 'run', 'backwards'] ['VERB', 'PART', 'VERB', 'ADV']
# ['run', 'backwards'] ['VERB', 'ADV']
# ['run', 'backwards', 'to', 'stand'] ['VERB', 'ADV', 'PART', 'VERB']
# ['run', 'backwards', 'turn', 'run', 'forward'] ['VERB', 'ADV', 'NOUN', 'VERB', 'ADV']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'right'] ['VERB', 'VERB', 'ADV']
# ['walk', 'turn', 'around'] ['VERB', 'VERB', 'PART']
# ['walk', 'to', 'hop', 'to', 'walk'] ['VERB', 'ADP', 'NOUN', 'PART', 'VERB']
# ['walk', 'to', 'hop', 'to', 'walk'] ['VERB', 'ADP', 'NOUN', 'PART', 'VERB']
# ['walk', 'to', 'leap', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['walk', 'to', 'leap', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['walk', 'to', 'leap', 'to', 'walk'] ['VERB', 'PART', 'VERB', 'PART', 'VERB']
# ['walk', 'to', 'pickup', 'box'] ['VERB', 'PART', 'NOUN', 'NOUN']
# ['walk', 'with', 'box'] ['VERB', 'ADP', 'NOUN']
# ['put', 'down', 'box', 'to', 'walk'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['put', 'down', 'box', 'to', 'walk'] ['VERB', 'PART', 'NOUN', 'PART', 'VERB']
# ['side', 'step', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['side', 'step', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['walk', 'to', 'crouch'] ['VERB', 'PART', 'VERB']
# ['walk', 'to', 'skip'] ['VERB', 'PART', 'VERB']
# ['skip', 'to', 'walk'] ['VERB', 'PART', 'VERB']
# ['stand', 'to', 'walk', 'backwards'] ['VERB', 'PART', 'VERB', 'ADV']
# ['walk', 'backwards'] ['VERB', 'ADV']
# ['walk', 'turn', 'leave'] ['VERB', 'NOUN', 'VERB']
# ['turn', 'around', 'right'] ['VERB', 'PART', 'ADV']
# ['side', 'step', 'right'] ['NOUN', 'NOUN', 'ADV']
# ['block', 'leave', 'high'] ['NOUN', 'VERB', 'ADJ']
# ['block', 'leave', 'low'] ['NOUN', 'VERB', 'ADJ']
# ['block', 'right', 'high'] ['VERB', 'ADV', 'ADJ']
# ['block', 'right', 'low'] ['VERB', 'ADV', 'ADJ']
# ['block', 'leave', 'middle'] ['NOUN', 'VERB', 'ADJ']
# ['block', 'right', 'middle'] ['VERB', 'ADV', 'NOUN']
# ['block', 'middle', 'high'] ['VERB', 'ADJ', 'ADJ']
# ['block', 'middle', 'low'] ['VERB', 'ADJ', 'ADJ']
# ['dodge', 'leave'] ['NOUN', 'VERB']
# ['dodge', 'leave'] ['NOUN', 'VERB']
# ['turn', 'around', 'leave'] ['VERB', 'PART', 'VERB']
# ['dodge', 'right'] ['VERB', 'ADV']
# ['duck', 'leave'] ['NOUN', 'VERB']
# ['duck', 'right'] ['NOUN', 'ADV']
# ['advance'] ['NOUN']
# ['quick', 'advance'] ['ADJ', 'NOUN']
# ['retreat'] ['NOUN']
# ['quick', 'retreat'] ['ADJ', 'NOUN']
# ['super', 'fast', 'advance'] ['ADV', 'ADJ', 'NOUN']
# ['bounce'] ['VERB']
# ['side', 'step', 'leave'] ['NOUN', 'NOUN', 'VERB']
# ['ericcamper'] ['NOUN']
# ['qkwalk'] ['NOUN']
# ['run'] ['VERB']
# ['sprint'] ['NOUN']
# ['walkdog'] ['NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['jump'] ['VERB']
# ['sit'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['sit'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['sit'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['sit'] ['VERB']
# ['motorcycle'] ['NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['rom'] ['NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper', 'rom'] ['VERB', 'NOUN']
# ['rom'] ['NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['rom'] ['NOUN']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['rom'] ['NOUN']
# ['knock'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper', 'rom'] ['VERB', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['scamper', 'rom'] ['VERB', 'NOUN']
# ['sit'] ['VERB']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['scamper'] ['VERB']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['sit'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['rom'] ['NOUN']
# ['sit'] ['VERB']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['kick'] ['VERB']
# ['kick'] ['VERB']
# ['circle', 'walk'] ['NOUN', 'NOUN']
# ['jump'] ['VERB']
# ['jump'] ['VERB']
# ['scamper'] ['VERB']
# ['rom'] ['NOUN']
# ['treadmill', 'norm'] ['NOUN', 'NOUN']
# ['treadmill', 'fast'] ['NOUN', 'ADV']
# ['treadmill', 'slow'] ['NOUN', 'ADJ']
# ['treadmill', 'jog'] ['NOUN', 'NOUN']
# ['motorcycle'] ['NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'walk'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['normal', 'jog'] ['ADJ', 'NOUN']
# ['knock'] ['VERB']
# ['knock'] ['VERB']
# ['sit'] ['VERB']
# ['sit'] ['VERB']
# ['lift', 'light'] ['VERB', 'NOUN']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['lift', 'heavy'] ['VERB', 'ADJ']
# ['catch', 'and', 'throw'] ['VERB', 'CCONJ', 'VERB']
# ['throw', 'hard'] ['VERB', 'ADV']
# ['throw', 'hard'] ['VERB', 'ADV']
# ...
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'bk'] ['X', 'X']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'dg'] ['X', 'NOUN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'mm'] ['X', 'PROPN']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['hdm', 'tr'] ['X', 'X']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['op'] ['NOUN']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['lar'] ['ADJ']
# ['rom'] ['NOUN']
# ['uarb'] ['NOUN']
# ['uar'] ['NOUN']
# ['uar'] ['NOUN']
# ['uar'] ['NOUN']
# ['uar'] ['NOUN']
# ['rom'] ['NOUN']
# ['uar'] ['NOUN']
# ['uar'] ['NOUN']
# ['ulra'] ['ADJ']
# ['ulra'] ['ADJ']
# ['ulrb'] ['ADJ']
# ['ulrc'] ['ADJ']
# ['ulrd'] ['ADJ']
# ['ulr'] ['PUNCT']
# ['ulr'] ['PUNCT']
# ['ulr'] ['PUNCT']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['misc'] ['NOUN']
# ['misc', 'dance', 'in', 'the', 'rain', 'kick'] ['NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN']
# ['stretch'] ['NOUN']
# ['army'] ['NOUN']
# ['jiggle'] ['VERB']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['irish', 'dance'] ['ADJ', 'NOUN']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['misc'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['misc'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['hip'] ['NOUN']
# ['jump', 'jack'] ['VERB', 'NOUN']
# ['misc'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['hip'] ['NOUN']
# ['light', 'hop', 'stiff'] ['ADJ', 'VERB', 'ADJ']
# ['misc'] ['NOUN']
# ['misc'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['jump', 'jack'] ['VERB', 'NOUN']
# ['light', 'hop', 'loose'] ['ADJ', 'VERB', 'ADJ']
# ['light', 'hop', 'stiff'] ['ADJ', 'VERB', 'ADJ']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['jump', 'jack'] ['VERB', 'NOUN']
# ['misc'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['ankle'] ['NOUN']
# ['hip'] ['NOUN']
# ['neck'] ['NOUN']
# ['salsa'] ['NOUN']
# ['salsa'] ['NOUN']
# ['shake', 'hip'] ['VERB', 'NOUN']
# ['shake', 'shoulder'] ['VERB', 'NOUN']
# ['shoulder'] ['NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['army'] ['NOUN']
# ['hip'] ['NOUN']
# ['misc'] ['NOUN']
# ['misc'] ['NOUN']
# ['squat', 'simple'] ['VERB', 'ADJ']
# ['hip'] ['NOUN']
# ['misc'] ['NOUN']
# ['side', 'to', 'side', 'hop'] ['NOUN', 'ADP', 'NOUN', 'NOUN']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['stretch'] ['NOUN']
# ['hip'] ['NOUN']
# ['light', 'hop', 'loose'] ['ADJ', 'VERB', 'ADJ']
# ['light', 'hop', 'stiff'] ['ADJ', 'VERB', 'ADJ']
# ['one', 'leg', 'loose'] ['NUM', 'NOUN', 'ADJ']
# ['side', 'to', 'side', 'hop'] ['NOUN', 'ADP', 'NOUN', 'VERB']
# ['simple', 'crouch'] ['ADJ', 'NOUN']
# ['jump', 'jack'] ['VERB', 'NOUN']
# ['light', 'hop', 'loose'] ['ADJ', 'VERB', 'ADJ']
# ['light', 'hop', 'stiff'] ['ADJ', 'VERB', 'ADJ']
# ['misc'] ['NOUN']
# ['stretch'] ['NOUN']
# ['jump', 'jack'] ['VERB', 'NOUN']
# ['light', 'hop', 'loose'] ['ADJ', 'VERB', 'ADJ']
# ['light', 'hop', 'stiff'] ['ADJ', 'VERB', 'ADJ']
# ['misc', 'dancing', 'hiphop'] ['NOUN', 'NOUN', 'NOUN']
# ['stretch'] ['NOUN']
# ['feetjump'] ['NOUN']
# ['backwardswalk'] ['NOUN']
# ['jog'] ['VERB']
# ['jumprope'] ['NOUN']
# ['sideskip'] ['PROPN']
# ['slowtrot'] ['NOUN']
# ['stomp'] ['VERB']
# ['walk'] ['VERB']
# ['balance'] ['NOUN']
# ['cartwheel'] ['NOUN']
# ['crawl'] ['VERB']
# ['walk'] ['VERB']
# ['chacha'] ['NOUN']
# ['skip'] ['VERB']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['yoga'] ['NOUN']
# ['jumpandroll'] ['NOUN']
# ['speedvault'] ['NOUN']
# ['speedvault'] ['NOUN']
# ['basickendo'] ['VERB']
# ['hopoverobstacle'] ['X']
# ['jumpoverobstacle'] ['NOUN']
# ['kendokata'] ['NOUN']
# ['kirikaeshi'] ['ADJ']
# ['jumpandroll'] ['NOUN']
# ['jumpingonbench'] ['NOUN']
# ['monkeyvault'] ['NOUN']
# ['parkourroll'] ['NOUN']
# ['runningonbench'] ['NOUN']
# ['runningonbench'] ['NOUN']
# ['speedvault'] ['NOUN']
# ['speedvault'] ['NOUN']
# ['wushukick'] ['NOUN']
# ['bridge'] ['NOUN']
# ['catwalk'] ['NOUN']
# ['danceturn'] ['NOUN']
# ['danceturn'] ['NOUN']
# ['moonwalk'] ['NOUN']
# ['tiptoe'] ['ADJ']
# ['traditionalchinesedance'] ['NOUN']
# ['walk'] ['VERB']
# ['xinjiang'] ['PROPN']
# ['xinjiang'] ['PROPN']
# ['ankle'] ['NOUN']
# ['atu'] ['PROPN']
# ['chicken', 'wing'] ['NOUN', 'NOUN']
# ['jiggle', 'on', 'toe'] ['VERB', 'PART', 'NOUN']
# ['knee'] ['NOUN']
# ['punch'] ['VERB']
# ['shake', 'hip'] ['VERB', 'NOUN']
# ['shake', 'shoulder'] ['VERB', 'NOUN']
# ['shoulder'] ['NOUN']
# ['side', 'hop'] ['NOUN', 'VERB']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['wrist', 'up', 'down'] ['NOUN', 'PART', 'PART']
# ['atusquat', 'sync'] ['ADJ', 'NOUN']
# ['clap', 'sync'] ['VERB', 'NOUN']
# ['dribble', 'kick', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['dribble', 'shoot', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['jump', 'jack', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['light', 'hop', 'loose', 'sync'] ['ADJ', 'VERB', 'ADJ', 'NOUN']
# ['punch', 'kick', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['run', 'on', 'the', 'spot', 'sync'] ['VERB', 'ADP', 'DET', 'NOUN', 'NOUN']
# ['special', 'move', 'sync'] ['ADJ', 'NOUN', 'NOUN']
# ['atusquat', 'sync'] ['ADJ', 'NOUN']
# ['clap', 'sync'] ['VERB', 'NOUN']
# ['dance', 'sync'] ['NOUN', 'NOUN']
# ['dribble', 'kick', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['hop', 'on', 'one', 'leg', 'sync'] ['NOUN', 'ADP', 'NUM', 'NOUN', 'NOUN']
# ['jump', 'jack', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['light', 'hop', 'loose', 'sync'] ['ADJ', 'VERB', 'ADJ', 'NOUN']
# ['punch', 'kick', 'sync'] ['VERB', 'NOUN', 'NOUN']
# ['act'] ['VERB']
# ['act'] ['VERB']
# ['act'] ['VERB']
# ['freestyle'] ['ADJ']
# ['freestyle'] ['ADJ']
# ['freestyle'] ['ADJ']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['act'] ['VERB']
# ['act'] ['VERB']
# ['act'] ['VERB']
# ['freestyle'] ['ADJ']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['act'] ['VERB']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['rom'] ['NOUN']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['walk'] ['VERB']
# ['freestyle'] ['ADJ']
# ['freestyle'] ['ADJ']
# ['rom'] ['NOUN']
# ['walk'] ['VERB']
# ['freestyle'] ['ADJ']
# ['freestyle'] ['ADJ']
# ['rom'] ['NOUN']
# ['walk'] ['VERB']
# ['airkick', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['airkick', 'jumpinplace'] ['NOUN', 'NOUN']
# ['airkick', 'longjump'] ['NOUN', 'NOUN']
# ['airkick', 'run'] ['NOUN', 'VERB']
# ['airkick', 'stand'] ['NOUN', 'NOUN']
# ['airkick', 'turntwist'] ['NOUN', 'NOUN']
# ['airkick', 'walkbackward'] ['NOUN', 'NOUN']
# ['crawl', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['crawl', 'jumpinplace'] ['VERB', 'ADJ']
# ['crawl', 'push'] ['VERB', 'NOUN']
# ['crawl', 'runbackward'] ['NOUN', 'NOUN']
# ['crawl', 'stand'] ['X', 'NOUN']
# ['crawl', 'walkbackward'] ['NOUN', 'NOUN']
# ['crouchwalk', 'crawl'] ['NOUN', 'NOUN']
# ['crouchwalk', 'jumpinplace'] ['NOUN', 'ADJ']
# ['crouchwalk', 'longjump'] ['NOUN', 'NOUN']
# ['crouchwalk', 'push'] ['NOUN', 'VERB']
# ['crouchwalk', 'runbackward'] ['NOUN', 'NOUN']
# ['crouchwalk', 'run'] ['NOUN', 'VERB']
# ['crouchwalk', 'stand'] ['NOUN', 'VERB']
# ['crouchwalk', 'stand'] ['NOUN', 'VERB']
# ['crouchwalk', 'turntwist'] ['NOUN', 'NOUN']
# ['crouchwalk', 'walk'] ['NOUN', 'NOUN']
# ['dance', 'jumpinplace'] ['NOUN', 'NOUN']
# ['dance', 'kick'] ['NOUN', 'NOUN']
# ['dance', 'longjump'] ['NOUN', 'NOUN']
# ['dance', 'push'] ['NOUN', 'NOUN']
# ['dance', 'runbackward'] ['NOUN', 'NOUN']
# ['dance', 'run'] ['NOUN', 'VERB']
# ['run', 'jumpinplace'] ['VERB', 'NOUN']
# ['run', 'longjump'] ['VERB', 'NOUN']
# ['run', 'stand'] ['VERB', 'NOUN']
# ['run', 'walk'] ['VERB', 'NOUN']
# ['sit', 'jumpinplace'] ['VERB', 'ADJ']
# ['sit', 'stand'] ['VERB', 'VERB']
# ['turntwist', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['turntwist', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['turntwist', 'kick'] ['NOUN', 'NOUN']
# ['turntwist', 'longjump'] ['NOUN', 'NOUN']
# ['turntwist', 'push'] ['NOUN', 'NOUN']
# ['turntwist', 'stand'] ['NOUN', 'NOUN']
# ['turntwist', 'walkbackward'] ['NOUN', 'NOUN']
# ['turntwist', 'walk'] ['NOUN', 'NOUN']
# ['jumpingjack', 'walk'] ['NOUN', 'VERB']
# ['jumpingtwist', 'jumpinplace'] ['ADJ', 'NOUN']
# ['jumpingtwist', 'run'] ['ADJ', 'VERB']
# ['jumpingtwist', 'stand'] ['ADJ', 'NOUN']
# ['jumpingtwist', 'turntwist'] ['ADJ', 'NOUN']
# ['jumpingtwist', 'walk'] ['ADJ', 'NOUN']
# ['jumpinplace', 'jumpingtwist'] ['ADJ', 'NOUN']
# ['jumpinplace', 'push'] ['ADJ', 'NOUN']
# ['jumpinplace', 'walkbackward'] ['ADJ', 'NOUN']
# ['kick', 'jumpinplace'] ['VERB', 'NOUN']
# ['kick', 'push'] ['VERB', 'NOUN']
# ['kick', 'stand'] ['VERB', 'NOUN']
# ['kick', 'walk'] ['VERB', 'NOUN']
# ['lob', 'turntwist'] ['NOUN', 'NOUN']
# ['punchboxe', 'jumpinplace'] ['VERB', 'NOUN']
# ['punchboxe', 'kick'] ['VERB', 'NOUN']
# ['punchboxe', 'push'] ['VERB', 'NOUN']
# ['punchboxe', 'run'] ['VERB', 'VERB']
# ['punchboxe', 'stand'] ['VERB', 'NOUN']
# ['punchboxe', 'walk'] ['VERB', 'NOUN']
# ['punchkarate', 'jumpingtwist'] ['ADJ', 'NOUN']
# ['punchkarate', 'kick'] ['ADJ', 'NOUN']
# ['punchkarate', 'longjump'] ['ADJ', 'NOUN']
# ['punchkarate', 'push'] ['ADJ', 'NOUN']
# ['punchkarate', 'stand'] ['ADJ', 'NOUN']
# ['punchkarate', 'walkbackward'] ['ADJ', 'NOUN']
# ['crouchwalk', 'kick'] ['NOUN', 'NOUN']
# ['dance', 'stand'] ['NOUN', 'NOUN']
# ['jumpingjack', 'turntwist'] ['NOUN', 'NOUN']
# ['punchkarate', 'walk'] ['ADJ', 'NOUN']
# ['twistdance', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['twistdance', 'kick'] ['NOUN', 'NOUN']
# ['twistdance', 'walk'] ['NOUN', 'NOUN']
# ['walkbackward', 'jumpinplace'] ['NOUN', 'ADJ']
# ['walkbackward', 'push'] ['NOUN', 'VERB']
# ['walkbackward', 'stand'] ['NOUN', 'VERB']
# ['walkbackward', 'turntwist'] ['NOUN', 'NOUN']
# ['walksideway', 'jumpingtwist'] ['NOUN', 'NOUN']
# ['walksideway', 'jumpinplace'] ['NOUN', 'ADJ']
# ['walksideway', 'kick'] ['NOUN', 'VERB']
# ['walksideway', 'push'] ['NOUN', 'VERB']
# ['walksideway', 'runbackward'] ['NOUN', 'NOUN']
# ['walksideway', 'run'] ['NOUN', 'VERB']
# ['walksideway', 'stand'] ['NOUN', 'VERB']
# ['walksideway', 'turntwist'] ['NOUN', 'NOUN']
# ['walksideway', 'walkbackward'] ['NOUN', 'NOUN']
# ['walksideway', 'walk'] ['NOUN', 'VERB']
# ['dance', 'turntwist'] ['NOUN', 'NOUN']
# ['dance', 'walk'] ['NOUN', 'NOUN']
# ['devishdance', 'jumpinplace'] ['NOUN', 'NOUN']
# ['devishdance', 'kick'] ['NOUN', 'NOUN']
# ['devishdance', 'longjump'] ['NOUN', 'NOUN']
# ['devishdance', 'stand'] ['NOUN', 'NOUN']
# ['devishdance', 'walkbackward'] ['NOUN', 'NOUN']
# ['gus', 'kick'] ['X', 'NOUN']
# ['joof', 'kick'] ['ADJ', 'NOUN']
# ['joof', 'longjump'] ['ADJ', 'NOUN']
# ['joof', 'push'] ['ADJ', 'NOUN']
# ['joof', 'runbackward'] ['ADJ', 'NOUN']
# ['joof', 'turntwist'] ['ADJ', 'NOUN']
# ['joof', 'walkbackward'] ['ADJ', 'NOUN']
# ['joof', 'walk'] ['ADJ', 'NOUN']
# ['jumpingjack', 'jumpingtwist'] ['NOUN', 'ADJ']
# ['jumpingjack', 'jumpinplace'] ['NOUN', 'ADJ']
# ['jumpingjack', 'kick'] ['NOUN', 'VERB']
# ['jumpingjack', 'longjump'] ['NOUN', 'VERB']
# ['jumpingjack', 'push'] ['NOUN', 'VERB']

# %%
output_lines = []
for path, fn, verbs in zip(file_list, filename_list, verb_list):
    output_lines.append(f'{path},{fn},{";".join(verbs)}')

with open(output_path, 'w') as output_file:
    output_file.write('\n'.join(output_lines))
